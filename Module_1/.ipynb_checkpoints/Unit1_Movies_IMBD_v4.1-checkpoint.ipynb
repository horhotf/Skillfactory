# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('~/movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id    budget    revenue                     original_title  \
# 848   tt1464174  32000000   83615414  Big Mommas: Like Father, Like Son
# 1222  tt2191701  80000000  246984278                        Grown Ups 2
# 1645  tt0324554  30000000   13001257                        Wicker Park
# 845   tt1462041  50000000   38502340                        Dream House
# 1089  tt0314331  40000000  244931766                      Love Actually
#
#                                                    cast        director  \
# 848   Portia Doubleday|Martin Lawrence|Brandon T. Ja...  John Whitesell
# 1222  Adam Sandler|Kevin James|Chris Rock|David Spad...    Dennis Dugan
# 1645  Josh Hartnett|Rose Byrne|Matthew Lillard|Diane...   Paul McGuigan
# 845   Daniel Craig|Naomi Watts|Rachel Weisz|Marton C...    Jim Sheridan
# 1089  Bill Nighy|Gregor Fisher|Colin Firth|Sienna Gu...  Richard Curtis
#
#                                                 tagline  \
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year  \
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000
#
#              profit
# count  1.889000e+03
# mean   1.010545e+08
# std    1.830733e+08
# min   -1.657101e+08
# 25%    5.000000e+06
# 50%    4.400041e+07
# 75%    1.201842e+08
# max    2.544506e+09

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

data['profit'] = data['revenue'] - data['budget']

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
answers['1'] = '+Pirates of the Caribbean: On Stranger Tides (tt1298650)'

# %%
data[(data.budget == data.budget.max())]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year     profit
# 723           6.3          2011  641683000

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = '+Gods and Generals (tt0279111)'

# %%
data[(data.runtime == data.runtime.max())]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year    profit
# 1157           5.8          2003 -43076064

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = '+Winnie the Pooh (tt1449283)'

# %%
data[(data.runtime == data.runtime.min())]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year    profit
# 768    4/13/2011           6.8          2011 -15540000

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '+109.7'

# %%
data.runtime.mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '+107'

# %%
data.runtime.median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
answers['6'] = '+Avatar (tt0499549)'

# %%
data[(data.profit == data.profit.max())]
# Out:
#        imdb_id     budget     revenue original_title  \
# 239  tt0499549  237000000  2781505847         Avatar
#
#                                                   cast       director  \
# 239  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                          tagline  \
# 239  Enter the World of Pandora.
#
#                                               overview  runtime  \
# 239  In the 22nd century, a paraplegic Marine is di...      162
#
#                                        genres  \
# 239  Action|Adventure|Fantasy|Science Fiction
#
#                                   production_companies release_date  \
# 239  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
#
#      vote_average  release_year      profit
# 239           7.1          2009  2544505847

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = '+The Lone Ranger (tt1210819)'

# %%
data[(data.profit == data.profit.min())]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '+1478'

# %%
len(data[(data.profit > 0)])
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = '+The Dark Knight (tt0468569)'

# %%
data_2008 = data[data.release_year == 2008]
data_2008[data_2008.revenue == data_2008.revenue.max()]
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit
# 599           8.1          2008  816921825

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = '+The Lone Ranger (tt1210819)'

# %%
data_12_14 = data[(data.release_year > 2011) & (data.release_year < 2015)]
data_12_14[data_12_14.profit == data_12_14.profit.min()]
# Out:
#         imdb_id     budget   revenue   original_title  \
# 1245  tt1210819  255000000  89289910  The Lone Ranger
#
#                                                    cast        director  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...  Gore Verbinski
#
#                       tagline  \
# 1245  Never Take Off the Mask
#
#                                                overview  runtime  \
# 1245  The Texas Rangers chase down a gang of outlaws...      149
#
#                         genres  \
# 1245  Action|Adventure|Western
#
#                                    production_companies release_date  \
# 1245  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
#
#       vote_average  release_year     profit
# 1245           6.0          2013 -165710090

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
answers['11'] = '+Drama'

# %%
genres_statistics = {} # массив жанров
for i in data.genres: # Бежим по всем фильмам
    mass = i.split("|") # вытаскиваем все жанры
    for j in mass:
        if j in genres_statistics: # если знаем такой жанр увеличиваем счетчик
            genres_statistics[j] += 1
        else: # иначе - добавляем новый со значением 1
            genres_statistics[j] = 1
dict(sorted(genres_statistics.items(), key=lambda item: item[1])) # сортируем по возрастанию
# Out:
# {'Foreign': 2,
#  'Documentary': 8,
#  'Western': 19,
#  'War': 58,
#  'History': 62,
#  'Music': 64,
#  'Animation': 139,
#  'Mystery': 168,
#  'Horror': 176,
#  'Fantasy': 222,
#  'Science Fiction': 248,
#  'Family': 260,
#  'Romance': 308,
#  'Crime': 315,
#  'Adventure': 415,
#  'Action': 582,
#  'Thriller': 596,
#  'Comedy': 683,
#  'Drama': 782}

# %% [markdown]
# ВАРИАНТ 2

# %%
import itertools
list_mass = data.genres.apply(lambda x: x.split("|")) # разбивка списка жанров по спискам 
list_mass_genres = list(itertools.chain(*list_mass)) # объединение списков в единый
genres_statistics = pd.Series(list_mass_genres).value_counts() # подсчет уникальных значений
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# dtype: int64

# %% [markdown]
# ВАРИАНТ 3

# %%
# собираем массив при помощи итераторов
list_mass = [word for list_genres in data.genres.apply(lambda x: x.split("|")) for word in list_genres]
# подсчет уникальных значений
genres_statistics = pd.Series(list_mass).value_counts()

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = '+Drama'

# %%
import itertools
list_mass = data.genres.apply(lambda x: x.split("|")) # разбивка списка жанров по спискам 
list_mass_genres = list(itertools.chain(*list_mass)) # объединение списков в единый
genres_statistics = pd.Series(list_mass_genres).value_counts() # подсчет уникальных значений

genres_profit_statistics = {} # массив прибыльных жанров
profit_data = data[data.profit > 0] # Series прибыльных фильмов
for film_genres in profit_data.genres: # Бежим по всем прибыльным фильмам
    for genre in genres_statistics.keys(): # Бежим по всем жанрам
        if genre in film_genres.split("|"): # если в фильме есть жанр
            if genre in genres_profit_statistics: # если знаем такой прибыльный жанр увеличиваем счетчик
                genres_profit_statistics[genre] += 1
            else: # иначе - добавляем новый со значением 1
                genres_profit_statistics[genre] = 1

genres_profit_statistics
# Out:
# {'Thriller': 446,
#  'Action': 444,
#  'Adventure': 337,
#  'Science Fiction': 195,
#  'Fantasy': 188,
#  'Crime': 231,
#  'Drama': 560,
#  'Western': 12,
#  'Comedy': 551,
#  'Family': 226,
#  'Animation': 120,
#  'Mystery': 119,
#  'Romance': 242,
#  'War': 41,
#  'History': 46,
#  'Music': 47,
#  'Horror': 150,
#  'Documentary': 7}

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
answers['13'] = '+Peter Jackson'

# %%
import itertools
list_mass_director = list(itertools.chain(*data.director.apply(lambda x: x.split("|")))) # объединение списков режисеров в единый
director_statistics = pd.Series(list_mass_director).value_counts() # подсчет уникальных значений
sum_revenue_director = {} # список сумм режисеров
for director in director_statistics.keys():
    director_data = data.revenue[data.director.str.contains(director) == True] # список фильмов режисера
    sum_revenue_director[director] = director_data.sum() # сумма сборов режисера
dict(sorted(sum_revenue_director.items(), key=lambda item: item[1])) # сортировка
# Out:
# {'Simon Hunter': 2033165,
#  'Keanu Reeves': 2054941,
#  'Paul Schrader': 2062066,
#  'Steven Shainberg': 2281089,
#  'David MichÃ´d': 2295423,
#  'Adam Wingard': 2367161,
#  'Zal Batmanglij': 2401510,
#  'Guillaume Canet': 2415472,
#  'Michael Cuesta': 2450846,
#  'James Cox': 2466444,
#  'David Mackenzie': 2500000,
#  'Dan Rush': 2614773,
#  'Roland JoffÃ©': 2626800,
#  'Liev Schreiber': 2697930,
#  'Susanne Bier': 2849142,
#  'Floria Sigismondi': 2995811,
#  'Henry Alex Rubin': 3428048,
#  'Don McKellar': 3430018,
#  'Rob Thomas': 3485127,
#  'RyÃ»hei Kitamura': 3533227,
#  'Jaco Van Dormael': 3547209,
#  'Dito Montiel': 3639345,
#  'Peter Bogdanovich': 3646994,
#  'William Dear': 3878993,
#  'Joe Cornish': 3964682,
#  'John Landis': 4349187,
#  'Jay Duplass': 4417580,
#  'Mark Duplass': 4417580,
#  'Jane Campion': 4440055,
#  'Paul Johansson': 4627375,
#  'David Barrett': 4636169,
#  'William Monahan': 4644108,
#  'Vipul Amrutlal Shah': 5000000,
#  'Davis Guggenheim': 5108820,
# ...

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = '+Robert Rodriguez'

# %%
data_action = data[data.genres.str.contains("Action") == True] # выборка фильмов по жанру Action
list_mass_action_director = list(itertools.chain(*data_action.director.apply(lambda x: x.split("|")))) # объединение списков режисеров в единый
action_director_statistics = pd.Series(list_mass_action_director).value_counts() # подсчет уникальных значений
dict(sorted(action_director_statistics.items(), key=lambda item: item[1])) # сортировка
# Out:
# {'David Leitch': 1,
#  'Chris Renaud': 1,
#  'Peter Farrelly': 1,
#  'Vicky Jenson': 1,
#  'Jay Chandrasekhar': 1,
#  'Dan Bradley': 1,
#  'Tony Bill': 1,
#  'John Bonito': 1,
#  'Alfonso CuarÃ³n': 1,
#  'Mike McCoy': 1,
#  'Danny Pang': 1,
#  'Julie Anne Robinson': 1,
#  'John Dahl': 1,
#  'Eric Brevig': 1,
#  'Henry Selick': 1,
#  'David Leland': 1,
#  'Joe Cornish': 1,
#  'Steve Purcell': 1,
#  'Christian Duguay': 1,
#  'Wayne Kramer': 1,
#  'George Miller': 1,
#  'Oliver Parker': 1,
#  'Karyn Kusama': 1,
#  'Brian Robbins': 1,
#  'Tony Gilroy': 1,
#  'Tom McGrath': 1,
#  'Hoyt Yeatman': 1,
#  'Gary Shore': 1,
#  'Mel Gibson': 1,
#  'Terry Gilliam': 1,
#  'Steve Carr': 1,
#  'Brian Levant': 1,
#  'Chad Stahelski': 1,
#  'Phillip Noyce': 1,
#  'Patrick Tatopoulos': 1,
#  'Rob Minkoff': 1,
#  'Trey Parker': 1,
#  'Joseph Kahn': 1,
#  'Colin Trevorrow': 1,
#  'MÃ¥ns MÃ¥rlind': 1,
#  'Miguel Sapochnik': 1,
#  'Luke Greenfield': 1,
#  'Bruce Hunt': 1,
#  'Roger Michell': 1,
# ...

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15'] = '+Chris Hemsworth'

# %%
data_2012 = data[data.release_year == 2012] #выборка фильмов с годом производства 2012
list_mass_2012_casts = list(itertools.chain(*data_2012.cast.apply(lambda x: x.split("|")))) # объединение списков актеров в единый
casts_2012_statistics = pd.Series(list_mass_2012_casts).value_counts() # подсчет уникальных значений

sum_revenue_casts = {} # список сумм актеров
for cast_one in casts_2012_statistics.keys():
    cast_data = data_2012.revenue[data_2012.cast.str.contains(cast_one) == True] # список фильмов актера
    sum_revenue_casts[cast_one] = cast_data.sum() # сумма сборов актера
dict(sorted(sum_revenue_casts.items(), key=lambda item: item[1])) # сортировка
# Out:
# {'Sami Gayle': 2106557,
#  'Nicolas Cage': 2106557,
#  'Danny Huston': 2106557,
#  'Josh Lucas': 2106557,
#  'Jason Bateman': 3428048,
#  'Hope Davis': 3428048,
#  'Paula Patton': 3428048,
#  'Michael Nyqvist': 3428048,
#  'Frank Grillo': 3428048,
#  '50 Cent': 4636169,
#  'Rosario Dawson': 4636169,
#  'Josh Duhamel': 4636169,
#  "Vincent D'Onofrio": 4636169,
#  'Juliette Binoche': 6063556,
#  'Paul Giamatti': 6063556,
#  'Sarah Gadon': 6063556,
#  'Samantha Morton': 6063556,
#  'James Kidnie': 8106475,
#  'Timothy Spall': 8106475,
#  'Heidi Hawkins': 8106475,
#  'Rosemarie DeWitt': 8138788,
#  'Matt Damon': 8138788,
#  'Lucas Black': 8138788,
#  'Jean-Luc Bilodeau': 8493728,
#  'Matt Bush': 8493728,
#  'Danielle Panabaker': 8493728,
#  'David Koechner': 8493728,
#  'Katrina Bowden': 8493728,
#  'Tom Sturridge': 8784318,
#  'Sam Riley': 8784318,
#  'Garrett Hedlund': 8784318,
#  "Peter O'Toole": 9622846,
#  'Andy GarcÃ\xada': 9622846,
#  'Oscar Isaac': 9622846,
# ...

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16'] = '+Matt Damon'

# %%
data_budget_up_mean = data[data.budget > data.budget.mean()] # выборка фильмов с бюджетом больще среднего
list_mass_casts_budget_up_mean = list(itertools.chain(*data_budget_up_mean.cast.apply(lambda x: x.split("|")))) # объединение списков в единый
casts_budget_up_mean_statistics = pd.Series(list_mass_casts_budget_up_mean).value_counts() # подсчет уникальных значений
dict(sorted(casts_budget_up_mean_statistics.items(), key=lambda item: item[1], reverse=True)) # сортировка
# Out:
# {'Matt Damon': 18,
#  'Adam Sandler': 17,
#  'Angelina Jolie': 16,
#  'Eddie Murphy': 15,
#  'Samuel L. Jackson': 15,
#  'Tom Cruise': 15,
#  'Russell Crowe': 14,
#  'Jamie Foxx': 14,
#  'Mark Wahlberg': 14,
#  'Hugh Jackman': 14,
#  'Ben Stiller': 14,
#  'Will Smith': 13,
#  'Jude Law': 13,
#  'Johnny Depp': 13,
#  'Bruce Willis': 13,
#  'Dwayne Johnson': 12,
#  'Ian McKellen': 12,
#  'Cameron Diaz': 12,
#  'Robert De Niro': 12,
#  'Owen Wilson': 12,
#  'Nicolas Cage': 12,
#  'Brad Pitt': 12,
#  'Leonardo DiCaprio': 11,
#  'Daniel Craig': 11,
#  'Steve Buscemi': 11,
#  'Robert Downey Jr.': 11,
#  'Denzel Washington': 10,
#  'Emma Watson': 10,
#  'Jack Black': 10,
#  'Orlando Bloom': 10,
#  'Mark Ruffalo': 10,
#  'Vin Diesel': 10,
#  'Gary Oldman': 10,
#  'Tom Hanks': 10,
#  'Michael Caine': 9,
#  'Colin Farrell': 9,
#  'Brendan Gleeson': 9,
#  'Rachel Weisz': 9,
#  'Paul Bettany': 9,
#  'Ewan McGregor': 9,
#  'Ralph Fiennes': 9,
#  'Halle Berry': 9,
#  'Cate Blanchett': 9,
# ...

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17'] = '+Action'

# %%
data_Nicolas_Cage = data[data.cast.str.contains("Nicolas Cage") == True] #выборка фильсов с участием Nicolas Cage
list_mass_Nicolas_Cage = list(itertools.chain(*data_Nicolas_Cage.genres.apply(lambda x: x.split("|")))) # объединение списков в единый
Nicolas_Cage_genres_statistics = pd.Series(list_mass_Nicolas_Cage).value_counts() # подсчет уникальных значений
dict(sorted(Nicolas_Cage_genres_statistics.items(), key=lambda item: item[1], reverse=True)) # сортировка
# Out:
# {'Action': 17,
#  'Thriller': 15,
#  'Drama': 12,
#  'Crime': 10,
#  'Fantasy': 8,
#  'Adventure': 7,
#  'Comedy': 6,
#  'Science Fiction': 4,
#  'Family': 3,
#  'Mystery': 3,
#  'Animation': 3,
#  'History': 2,
#  'War': 1,
#  'Horror': 1,
#  'Romance': 1}

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18'] = '+K-19: The Widowmaker (tt0267626)'

# %%
data_Paramount_Pictures = data[data.production_companies.str.contains("Paramount Pictures") == True] # выборка фильмов Paramount Pictures 
data_Paramount_Pictures[data_Paramount_Pictures.profit == data_Paramount_Pictures.profit.min()] # самый убыточный фильм
# Out:
#        imdb_id     budget   revenue        original_title  \
# 925  tt0267626  100000000  35168966  K-19: The Widowmaker
#
#                                                   cast         director  \
# 925  Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
#
#                       tagline  \
# 925  Fate has found its hero.
#
#                                               overview  runtime  \
# 925  When Russia's first nuclear submarine malfunct...      138
#
#                      genres  \
# 925  Thriller|Drama|History
#
#                                   production_companies release_date  \
# 925  Paramount Pictures|Intermedia Films|National G...    7/19/2002
#
#      vote_average  release_year    profit
# 925           6.0          2002 -64831034

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = '+2015'

# %%
data_revenue_years = data.groupby(['release_year']).sum() #группировка по годам
display(data_revenue_years[data_revenue_years.revenue == data_revenue_years.revenue.max()]) # подсчет
# Out:
#                   budget      revenue  runtime  vote_average       profit
# release_year
# 2015          6780630004  25449202382    13355         755.2  18668572378

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20'] = '+2014'

# %%
data_Warner_Bros = data[data.production_companies.str.contains("Warner Bros") == True] # выборка фильмов Warner Bros
data_revenue_years = data_Warner_Bros.groupby(['release_year']).sum() #группировка по годам
display(data_revenue_years[data_revenue_years.profit == data_revenue_years.profit.max()]) # подсчет
# Out:
#                  budget     revenue  runtime  vote_average      profit
# release_year
# 2014          947600000  3243064519     1576          88.9  2295464519

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21'] = '+Сентябрь'

# %%
import datetime
#парсим дату, группируем по месяцам, считаем фильмы
grouped_data_mounth = data.groupby(pd.DatetimeIndex(data['release_date']).month)['imdb_id'].count().sort_values(ascending=False)
grouped_data_mounth
# Out:
# release_date
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22'] = '+450'

# %%
#парсим дату, группируем по месяцам, считаем фильмы
grouped_data_mounth = data.groupby(pd.DatetimeIndex(data['release_date']).month)['imdb_id'].count().sort_values(ascending=False)

# суммируем летние месяцы 
count_summer_films = grouped_data_mounth[6]+grouped_data_mounth[7]+grouped_data_mounth[8] 
count_summer_films
# Out:
# 450

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
answers['23'] = '+Peter Jackson'

# %%
#фильмы выпущенные зимой
data_winter_films = data[(pd.DatetimeIndex(data['release_date']).month == 12) 
                         | (pd.DatetimeIndex(data['release_date']).month == 1) 
                         | (pd.DatetimeIndex(data['release_date']).month == 2)]

list_mass_film_winter_director = list(itertools.chain(*data_winter_films.director.apply(lambda x: x.split("|")))) # объединение списков в единый
winter_director_statistics = pd.Series(list_mass_film_winter_director).value_counts() # подсчет уникальных значений
dict(sorted(winter_director_statistics.items(), key=lambda item: item[1])) # сортировка
# Out:
# {'Todd Edwards': 1,
#  'Christopher Miller': 1,
#  'Greg Mottola': 1,
#  'Julie Anne Robinson': 1,
#  'Akiva Goldsman': 1,
#  'Roger Michell': 1,
#  'Chris Columbus': 1,
#  'Tim Story': 1,
#  'Neil Nightingale': 1,
#  'David Koepp': 1,
#  'Peter Webber': 1,
#  'Antoine Fuqua': 1,
#  'Ava DuVernay': 1,
#  'Jay Russell': 1,
#  'John Musker': 1,
#  'Alejandro GonzÃ¡lez IÃ±Ã¡rritu': 1,
#  'Chris Gorak': 1,
#  'Albert Hughes': 1,
#  'Cory Edwards': 1,
#  'Geoffrey Sax': 1,
#  'Justin Lin': 1,
#  "Gavin O'Connor": 1,
#  'Miguel Arteta': 1,
#  'Jim Gillespie': 1,
#  'Jonathan van Tulleken': 1,
#  'Angelina Jolie': 1,
#  'Uwe Boll': 1,
#  'Nick Cassavetes': 1,
#  'Mark Neveldine': 1,
#  'Ben Garant': 1,
#  'Tom Shadyac': 1,
#  'Elizabeth Banks': 1,
#  'Stephen Kay': 1,
#  'Will Gluck': 1,
#  'Anand Tucker': 1,
#  'Rodrigo GarcÃ\xada': 1,
#  'Patrick Tatopoulos': 1,
#  'Lee Tamahori': 1,
#  'Bill Condon': 1,
#  'Rob Bowman': 1,
#  'Paul W.S. Anderson': 1,
#  'Ric Roman Waugh': 1,
# ...

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24'] = '+Four By Two Productions'

# %%
import itertools
list_production_companies = list(itertools.chain(*data.production_companies.apply(lambda x: x.split("|")))) # объединение списков в единый
production_companies_statistics = pd.Series(list_production_companies).value_counts() # подсчет уникальных значений

len_title_statistics = {} # массив длин названий фильмов 
for i in range(len(data.original_title)):
    length = len(data.original_title[i])
    mass_company = data.production_companies[i].split("|") # получаем список компаний фильма
    for company in mass_company:
        if company in len_title_statistics: # если знаем такую компанию прибавляем длину названия ее фильма
            len_title_statistics[company] += length
        else: # иначе - добавляем новый со значением длины названия фильма
            len_title_statistics[company] = length


norm_len_title_by_comp = {}
for comp in production_companies_statistics.keys():
    # оценка средней длины названия фильма
    norm_len_title_by_comp[comp] = len_title_statistics[comp] / production_companies_statistics[comp]
    
dict(sorted(norm_len_title_by_comp.items(), key=lambda item: item[1], reverse=True)) # сортировка
# Out:
# {'Four By Two Productions': 83.0,
#  'Jim Henson Company, The': 59.0,
#  'Dos Corazones': 47.0,
#  'Polsky Films': 46.0,
#  'Museum Canada Productions': 46.0,
#  'The Saul Zaentz Company': 43.0,
#  'Lucasfilm': 41.5,
#  'Second Mate Productions': 41.0,
#  'Zohar International': 41.0,
#  'Harry Potter Publishing Rights': 41.0,
#  '3Foot7': 41.0,
#  'Iron Film': 41.0,
#  'TSBD Canada Productions': 41.0,
#  'Total Entertainment': 41.0,
#  'Cool Music': 41.0,
#  'Propeler': 40.0,
#  'Nickelodeon Animation Studios': 40.0,
#  'Ozumi Films': 40.0,
#  'United Plankton Pictures': 40.0,
#  'P of A Productions Limited': 40.0,
#  'Samuel Goldwyn Films': 39.0,
#  'MIRACLE Productions GmbH & Co. KG': 39.0,
#  'The Javelina Film Company': 39.0,
#  'Alberta Film Entertainment': 38.0,
#  'Chris Brinker Productions': 38.0,
#  'Natural Nylon Entertainment': 37.0,
#  'Riff Raff Film Productions': 37.0,
#  'Aramid Entertainment Fund': 37.0,
#  'Filmauro': 37.0,
#  'Lipsync Productions': 37.0,
# ...

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25'] = '+Midnight Picture Show'

# %%
import itertools
list_production_companies = list(itertools.chain(*data.production_companies.apply(lambda x: x.split("|")))) # объединение списков в единый
production_companies_statistics = pd.Series(list_production_companies).value_counts() # подсчет уникальных значений

len_overview_statistics = {} # массив длин описаний фильмов 
for i in range(len(data.overview)):
    length = len(data.overview[i].split(" "))
    mass_company = data.production_companies[i].split("|") # получаем список компаний фильма
    for company in mass_company:
        if company in len_overview_statistics: # если знаем такую компанию прибавляем длину описания ее фильма
            len_overview_statistics[company] += length
        else: # иначе - добавляем новый со значением длины описания фильма
            len_overview_statistics[company] = length


norm_len_overview_by_comp = {}
for comp in production_companies_statistics.keys():
    # расчет средняя длины описания фильма
    norm_len_overview_by_comp[comp] = len_overview_statistics[comp] / production_companies_statistics[comp]
dict(sorted(norm_len_overview_by_comp.items(), key=lambda item: item[1], reverse=True)) # сортировка
# Out:
# {'Midnight Picture Show': 175.0,
#  'Room 9 Entertainment': 161.0,
#  'Heineken Branded Entertainment': 161.0,
#  '98 MPH Productions': 159.0,
#  'Brookwell-McNamara Entertainment': 156.0,
#  'Lions Gate Family Entertainment': 152.0,
#  'Crest Animation Productions': 152.0,
#  'Art Pictures Studio': 147.0,
#  'Cinema Gypsy Productions': 144.0,
#  'Starbucks Entertainment': 144.0,
#  'Wayfare Entertainment': 138.0,
#  'Sanctum Australia': 138.0,
#  'Great Wight Productions/ Osford Films': 138.0,
#  'Sudden Storm Productions': 134.0,
#  'Magical Elves Productions': 132.0,
#  'Scooter Braun Films': 132.0,
#  'Disney Double Dare You (DDY)': 130.0,
#  'K. JAM Media': 128.0,
#  'Radical Studios': 127.5,
#  'Silent Hill DCP Inc.': 126.0,
#  'Konami': 126.0,
#  'Innocence Productions': 122.0,
#  'Oceana Media Finance': 122.0,
#  'Omega Entertainment': 122.0,
#  'Pantheon Entertainment Corporation': 122.0,
#  'David Ladd Films': 119.5,
#  'O.N.C. Entertainment': 117.0,
# ...

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = '+Inside Out, The Dark Knight, 12 Years a Slave'

# %%
data_1_persent_best_films = data[data['vote_average'] > data['vote_average'].quantile(q=0.99)] #расчет 1 процента
data_1_persent_best_films
# Out:
#         imdb_id     budget     revenue  \
# 9     tt2096673  175000000   853708609
# 34    tt3170832    6000000    35401758
# 118   tt0816692  165000000   621752480
# 119   tt2015381  170000000   773312399
# 125   tt2084970   14000000   233555708
# 128   tt2267998   61000000   369330363
# 138   tt2278388   30000000   174600318
# 370   tt1375666  160000000   825500000
# 599   tt0468569  185000000  1001921825
# 872   tt0253474   35000000   120072577
# 1081  tt0167260   94000000  1118888979
# 1183  tt0993846  100000000   392000694
# 1191  tt2024544   20000000   187000000
# 1800  tt0209144    9000000    39723096
#
#                                      original_title  \
# 9                                        Inside Out
# 34                                             Room
# 118                                    Interstellar
# 119                         Guardians of the Galaxy
# 125                              The Imitation Game
# ...

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
answers['27'] = '+Daniel Radcliffe,Rupert Grint'

# %%
import itertools
list_mass_casts = data.cast.apply(lambda x: x.split("|")) # список актеровов по фильмам 

couple_cast = {}

for film in list_mass_casts: # по каждому фильму
    for act1 in range(0,len(film)): # полный пербор актеров фильма 
        for act2 in range(act1+1,len(film)): # и с кем они снимались
            string = str(film[act1]) + "," + str(film[act2]) # формируем пары
            if string in couple_cast: # если знаем такую пару - увеличиваем счетчик
                couple_cast[string] += 1
            else: # иначе - добавляем новую со значением 1
                couple_cast[string] = 1
dict(sorted(couple_cast.items(), key=lambda item: item[1], reverse=True)) # сортировка
# Out:
# {'Daniel Radcliffe,Rupert Grint': 8,
#  'Daniel Radcliffe,Emma Watson': 8,
#  'Rupert Grint,Emma Watson': 7,
#  'Ben Stiller,Owen Wilson': 6,
#  'Johnny Depp,Helena Bonham Carter': 6,
#  'Adam Sandler,Kevin James': 5,
#  'Hugh Jackman,Ian McKellen': 5,
#  'Kristen Stewart,Robert Pattinson': 5,
#  'Kristen Stewart,Taylor Lautner': 5,
#  'Robert Pattinson,Taylor Lautner': 5,
#  'Jennifer Lawrence,Josh Hutcherson': 4,
#  'Jennifer Lawrence,Liam Hemsworth': 4,
#  'Jennifer Lawrence,Woody Harrelson': 4,
#  'Josh Hutcherson,Liam Hemsworth': 4,
#  'Josh Hutcherson,Woody Harrelson': 4,
#  'Liam Hemsworth,Woody Harrelson': 4,
#  'Tobin Bell,Costas Mandylor': 4,
#  'Tobin Bell,Betsy Russell': 4,
#  'Costas Mandylor,Betsy Russell': 4,
#  'Vin Diesel,Jordana Brewster': 4,
#  'Paul Walker,Jordana Brewster': 4,
#  'Mike Myers,Eddie Murphy': 4,
#  'Mike Myers,Cameron Diaz': 4,
#  'Eddie Murphy,Cameron Diaz': 4,
#  'Kristen Stewart,Peter Facinelli': 4,
#  'Robert Pattinson,Peter Facinelli': 4,
# ...

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '+Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '+Gods and Generals (tt0279111)',
#  '3': '+Winnie the Pooh (tt1449283)',
#  '4': '+109.7',
#  '5': '+107',
#  '6': '+Avatar (tt0499549)',
#  '7': '+The Lone Ranger (tt1210819)',
#  '8': '+1478',
#  '9': '+The Dark Knight (tt0468569)',
#  '10': '+The Lone Ranger (tt1210819)',
#  '11': '+Drama',
#  '12': '+Drama',
#  '13': '+Peter Jackson',
#  '14': '+Robert Rodriguez',
#  '15': '+Chris Hemsworth',
#  '16': '+Matt Damon',
#  '17': '+Action',
#  '18': '+K-19: The Widowmaker (tt0267626)',
#  '19': '+2015',
#  '20': '+2014',
#  '21': '+Сентябрь',
#  '22': '+450',
#  '23': '+Peter Jackson',
#  '24': '+Four By Two Productions',
#  '25': '+Midnight Picture Show',
#  '26': '+Inside Out, The Dark Knight, 12 Years a Slave',
#  '27': '+Daniel Radcliffe,Rupert Grint'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
